# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("baseball.csv")
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# The data set has 30 rows and 17 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# The data frame has 30 rows and 17 columns. All the columns have 30 non-null values. All columns are of integer data type ecxept ERA which is a float data type.

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# The columns W,R,AB,H,2B,3B,HR,BB,SO,SB,RA,ER,CG,SHO,SV and E are of integer data type and ERA is a float data type.

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no null value present in the dataset.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#Statistical summary
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# All the columns count is 30 there is no missing value in the dataset.
#
# The mean is more than median in H,HR and E.There is a difference between 75th percentile and Max, So outliers will be present.
#
# The average of the columns are W-80.96,R-688.23,AB-5516.26,H-1403.53,2B-274.73,3B-31.30,HR-163.63,BB-469.10,SO-1248.20,SB-83.50,RA-688.23,ER-635.83,ERA-3.95,CG-3.46,SHO-11.30,SV-43.06 and E-94.33.

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The columns RA,ER,ERA are highly correlated to each others. SHO,SV are negatively correlated to RA,ER and ERA.
#
# The target/output variable W is positively correlated to R,H,2B,HR,BB,SO,CG,SHO and SV. The target variable negatively correlated to AB,3B,SB,RA,ER,ERA and E.
#
# The change in the Saves in the columns will effect the Wins in the dataset.

# %% [markdown]
# Data Visualization

# %%
#Checking data distribution using violinplot
plt.figure(figsize=(20,25))
plotnumber=1

for column in df:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.violinplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# The majority data distribution in W is between 70 and 90.
#
# The majority data distribution in R is between 650 and 720.
#
# The majority data distribution in AB is between 5470 and 5580.
#
# The majority data distribution in H is between 1350 and 1400.
#
# The majority data distribution in 2B is between 260 and 290.
#
# The majority data distribution in 3B is between 25 and 40.
#
# The majority data distribution in HR is between 130 and 170.
#
# The majority data distribution in BB is between 425 and 500.
#
# The majority data distribution in SO is between 1200 and 1350.
#
# The majority data distribution in SB is between 60 and 100.
#
# The majority data distribution in RA is between 650 and 750.
#
# The majority data distribution in ER is between 600 and 700.
#
# The majority data distribution in ERA is between 3.5 and 4.5.
#
# The majority data distribution in CG is between 1 and 5.
#
# The majority data distribution in SHO is between 10 and 15.
#
# The majority data distribution in SV is between 35 and 50.
#
# The majority data distribution in E is between 80 and 100.

# %%
#Checking the data distribution to findout the skewness
plt.figure(figsize=(20,25))
plotnumber=1

for column in df:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# Data distribution is looking good. Small skewness is present

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Skewness is not present in the columns.

# %%
#Skewness Removing

# %%
df['R']=np.sqrt(df['R'])
sns.distplot(df['R'],color='y')
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
df['H']=np.sqrt(df['H'])
sns.distplot(df['H'],color='y')
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
df['CG']=np.sqrt(df['CG'])
sns.distplot(df['CG'],color='y')
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
df['E']=np.sqrt(df['E'])
sns.distplot(df['E'],color='y')
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %%
df.skew()
# Out:
# W      0.047089
# R      0.968676
# AB     0.183437
# H      0.649567
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.311476
# SHO    0.565790
# SV     0.657524
# E      0.763487
# dtype: float64

# %% [markdown]
# Skewness is good enough.

# %%
#Checking for the outliers
plt.figure(figsize=(20,25))
plotnumber=1

for column in df:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        (df[column]).plot.box()
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# Outliers are present in R,ERA,SHO,SV and E.

# %% [markdown]
# #Regression plot

# %%
sns.regplot(x=df['R'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %% [markdown]
# Positive linear relation between R and W.

# %%
sns.regplot(x=df['AB'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %% [markdown]
# Negative linear relation between AB and W.

# %%
sns.regplot(x=df['H'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %% [markdown]
# No linear relation between H and W.

# %%
sns.regplot(x=df['2B'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %% [markdown]
# Positive linear relation between 2B and W.

# %%
sns.regplot(x=df['3B'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %% [markdown]
# Negative linear relation between 3B and W.

# %%
sns.regplot(x=df['HR'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %% [markdown]
# Positive linear relation between HR and W.

# %%
sns.regplot(x=df['BB'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %% [markdown]
# Positive linear relation between BB and W.

# %%
sns.regplot(x=df['SO'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %% [markdown]
# Positive linear relation between SO and W.

# %%
sns.regplot(x=df['SB'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %% [markdown]
# Negative linear relation between SB and W.

# %%
sns.regplot(x=df['RA'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %% [markdown]
# Negative linear relation between RA and W.

# %%
sns.regplot(x=df['ER'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %% [markdown]
# Negative linear relation between ER and W.

# %%
sns.regplot(x=df['ERA'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %% [markdown]
# Negative linear relation between ERA and W.

# %%
sns.regplot(x=df['CG'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %% [markdown]
# No linear relation between CG and W.

# %%
sns.regplot(x=df['SHO'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %% [markdown]
# Positive linear relation between SHO and W.

# %%
sns.regplot(x=df['SV'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %% [markdown]
# Positive linear relation between SV and W.

# %%
sns.regplot(x=df['E'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %% [markdown]
# Negative linear relation between E and W.

# %% [markdown]
# #Residual plot

# %%
sns.residplot(x=df['R'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.residplot(x=df['AB'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.residplot(x=df['H'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.residplot(x=df['2B'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
sns.residplot(x=df['3B'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
sns.residplot(x=df['HR'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
sns.residplot(x=df['BB'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
sns.residplot(x=df['SO'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
sns.residplot(x=df['SB'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
sns.residplot(x=df['RA'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
sns.residplot(x=df['ER'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.residplot(x=df['ERA'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
sns.residplot(x=df['CG'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
sns.residplot(x=df['SHO'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
sns.residplot(x=df['SV'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %%
sns.residplot(x=df['E'],y=df['W'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='SV',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %% [markdown]
# When SV is increasing W is also increasing.

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='2B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %% [markdown]
# W is decreasing with respect to increase in ER.

# %%
sns.jointplot(x='SV',y='W',data=df)

# %% [markdown]
# W is increasing with respect to increase in SV.

# %%
sns.jointplot(x='RA',y='ER',data=df)

# %% [markdown]
# RA and ER is correlated to each other.

# %%
sns.jointplot(x='SHO',y='W',data=df)

# %%
sns.jointplot(x='BB',y='W',data=df)

# %%
sns.jointplot(x='ER',y='W',data=df)

# %%
sns.jointplot(x='ERA',y='W',data=df)

# %%
sns.jointplot(x='RA',y='W',data=df)

# %%
plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# The correlation between target variable W and the input variables is showing above.
#
# Positive correlation - SV,SHO,BB,R,2B,HR,SO,CG and H.
#
# Negative correlation - ERA,ER,RA,3B,SB,AB and E.

# %%
sns.pairplot(df)

# %%
#The input variables RA and ERA are negatively correlated to the output variable W, so removing them from the dataframe.
df=df.drop(['RA','ERA'],axis=1)

# %%
df.head()
# Out:
#     W          R    AB          H   2B  3B   HR   BB    SO   SB   ER  \
# 0  95  26.907248  5575  38.691084  300  42  139  383   973  104  601
# 1  83  26.381812  5467  36.728735  277  44  156  439  1264   70  653
# 2  81  25.865034  5439  37.349699  303  29  141  533  1157   86  584
# 3  76  24.939928  5533  37.161808  260  27  136  404  1231   68  643
# 4  74  26.248809  5605  38.923001  289  49  151  455  1259   83  746
#
#          CG  SHO  SV          E
# 0  1.414214    8  56   9.380832
# 1  1.414214   12  45   9.273618
# 2  3.316625   10  38   8.888194
# 3  2.645751    9  37  10.049876
# 4  2.645751   12  35   9.273618

# %%
#Finding outliers
from scipy.stats import zscore

z=np.abs(zscore(df))
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
#Removing outliers
dfnew=df[(z<3).all(axis=1)]
print('dfnew.shape = ',dfnew.shape)
df=dfnew
# Out:
# dfnew.shape =  (29, 15)

# %%
data_loss=(30-29)/30*100
data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# 3.33% Data loss after outliers removed.

# %%
#Separating dependent and independent variables

X=df.drop('W',axis=1)
Y=df['W']
print(len(X),len(Y))
# Out:
# 29 29

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.395249 -0.085780 -0.019562  0.384886 -0.206737  0.245697
# R    0.395249  1.000000  0.437413  0.430212  0.473663  0.137818  0.589594
# AB  -0.085780  0.437413  1.000000  0.769684  0.490752  0.445604 -0.064653
# H   -0.019562  0.430212  0.769684  1.000000  0.527700  0.580906 -0.218968
# 2B   0.384886  0.473663  0.490752  0.527700  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.137818  0.445604  0.580906  0.342419  1.000000 -0.369299
# HR   0.245697  0.589594 -0.064653 -0.218968 -0.098695 -0.369299  1.000000
# BB   0.447513  0.259048 -0.137850 -0.222036  0.211243 -0.404852  0.336814
# SO   0.156469  0.088220 -0.111243 -0.372596 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.074377  0.373674  0.419058  0.194308  0.483818 -0.166072
# ER  -0.815308  0.000026  0.309146  0.280268 -0.224993  0.333731 -0.062094
# CG  -0.003340  0.142005 -0.064516  0.053891  0.256132  0.009499  0.103823
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scale=MinMaxScaler()
X_s=scale.fit_transform(X)
X_s
# Out:
# array([[0.80197791, 0.71969697, 0.90855707, 0.95522388, 0.80555556,
#         0.3       , 0.04166667, 0.        , 0.66666667, 0.38317757,
#         0.42640143, 0.23529412, 0.82352941, 0.28095777],
#        [0.66008823, 0.31060606, 0.13481818, 0.6119403 , 0.86111111,
#         0.43076923, 0.33333333, 0.53394495, 0.28888889, 0.54517134,
#         0.42640143, 0.47058824, 0.5       , 0.23915473],
#        [0.52053671, 0.20454545, 0.37965923, 1.        , 0.44444444,
#         0.31538462, 0.82291667, 0.33761468, 0.46666667, 0.33021807,
#         1.        , 0.35294118, 0.29411765, 0.08887541],
#        [0.27071937, 0.56060606, 0.3055755 , 0.35820896, 0.38888889,
#         0.27692308, 0.15104167, 0.4733945 , 0.26666667, 0.51401869,
#         0.79772404, 0.29411765, 0.26470588, 0.54182234],
#        [0.62417202, 0.83333333, 1.        , 0.79104478, 1.        ,
#         0.39230769, 0.41666667, 0.52477064, 0.43333333, 0.83489097,
#         0.79772404, 0.47058824, 0.20588235, 0.23915473],
# ...

# %%
from sklearn.preprocessing import StandardScaler

scale=StandardScaler()
X_scale=scale.fit_transform(X_s)
X_scale
# Out:
# array([[ 0.95651645,  0.83008422,  1.73108753,  1.55653766,  1.01084549,
#         -0.76586314, -1.53635899, -2.72762331,  0.9059529 , -0.51114812,
#         -0.25354897, -0.81326172,  1.64315663, -0.45432526],
#        [ 0.34416795, -0.70283074, -0.94430524,  0.20117132,  1.20891656,
#         -0.18138864, -0.49502051,  0.12189552, -0.58531515,  0.23216082,
#         -0.25354897,  0.15929869,  0.21100645, -0.60761852],
#        [-0.25808975, -1.10025314, -0.097707  ,  1.73332457, -0.2766165 ,
#         -0.69710144,  1.25294051, -0.9258657 ,  0.11645805, -0.75415297,
#          2.02046293, -0.32698152, -0.70036184, -1.15869812],
#        [-1.33621796,  0.23395062, -0.35386977, -0.8006212 , -0.47468758,
#         -0.8690057 , -1.14585706, -0.20124579, -0.6730368 ,  0.08921679,
#          1.21854679, -0.57012162, -0.83055731,  0.50227443],
#        [ 0.18916563,  1.25589393,  2.047274  ,  0.90831897,  1.70409425,
# ...

# %% [markdown]
# Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error

lr=LinearRegression()
ls=Lasso()
rd=Ridge()
sv=SVR()
dt=DecisionTreeRegressor()
rf=RandomForestRegressor()

# %% [markdown]
# Linear Regression

# %%
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.3,random_state=i)
    lr.fit(x_train,y_train)
    predtr=lr.predict(x_train)
    predte=lr.predict(x_test)
    print("At random state ",i,"traning accuracy is : ",r2_score(y_train,predtr))
    print("At random state ",i,"testing accuracy is : ",r2_score(y_test,predte))
    print('\n')
# Out:
# At random state  1 traning accuracy is :  0.9779072682871705
# At random state  1 testing accuracy is :  0.3074892949820931
#
#
# At random state  2 traning accuracy is :  0.9550130750009818
# At random state  2 testing accuracy is :  -0.22338632693342553
#
#
# At random state  3 traning accuracy is :  0.9674620517770034
# At random state  3 testing accuracy is :  0.33246926153662726
#
#
# At random state  4 traning accuracy is :  0.9616798774089563
# At random state  4 testing accuracy is :  0.7631726642791412
#
#
# At random state  5 traning accuracy is :  0.9656778229709228
# At random state  5 testing accuracy is :  0.2912164985107194
#
#
# At random state  6 traning accuracy is :  0.9591632126503018
# At random state  6 testing accuracy is :  0.564549452862819
#
#
# At random state  7 traning accuracy is :  0.9367957917147467
# At random state  7 testing accuracy is :  0.790720381193126
#
#
# At random state  8 traning accuracy is :  0.9732920241880544
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.3,random_state=42)

lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
print(r2_score(y_test,predlr))
mean_squared_error(y_test,predlr)
# Out:
# 0.860348508175662
# 13.689294383768438

# %% [markdown]
# Lasso and Ridge Regularization

# %%
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.3,random_state=i)
    ls.fit(x_train,y_train)
    predtr=ls.predict(x_train)
    predte=ls.predict(x_test)
    print("At random state ",i,"traning accuracy is : ",r2_score(y_train,predtr))
    print("At random state ",i,"testing accuracy is : ",r2_score(y_test,predte))
    print('\n')
# Out:
# At random state  1 traning accuracy is :  0.8416732665033917
# At random state  1 testing accuracy is :  0.9439932672226318
#
#
# At random state  2 traning accuracy is :  0.870482516220152
# At random state  2 testing accuracy is :  0.4876548542520047
#
#
# At random state  3 traning accuracy is :  0.8848649175172059
# At random state  3 testing accuracy is :  0.7810404446577558
#
#
# At random state  4 traning accuracy is :  0.8762779467001076
# At random state  4 testing accuracy is :  0.8607530536652993
#
#
# At random state  5 traning accuracy is :  0.9029920825140975
# At random state  5 testing accuracy is :  0.754694017164521
#
#
# At random state  6 traning accuracy is :  0.9018151757293177
# At random state  6 testing accuracy is :  0.8303424950166871
#
#
# At random state  7 traning accuracy is :  0.8802139285798634
# At random state  7 testing accuracy is :  0.7564868617655724
#
#
# At random state  8 traning accuracy is :  0.8933062776899194
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.3,random_state=53)

ls.fit(x_train,y_train)
predls=ls.predict(x_test)
print(r2_score(y_test,predls))
mean_squared_error(y_test,predls)
# Out:
# 0.8782417669518785
# 12.987544858466288

# %%
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.3,random_state=i)
    rd.fit(x_train,y_train)
    predtr=rd.predict(x_train)
    predte=rd.predict(x_test)
    print("At random state ",i,"traning accuracy is : ",r2_score(y_train,predtr))
    print("At random state ",i,"testing accuracy is : ",r2_score(y_test,predte))
    print('\n')
# Out:
# At random state  1 traning accuracy is :  0.9327584056296189
# At random state  1 testing accuracy is :  0.8903372943996708
#
#
# At random state  2 traning accuracy is :  0.9438288549316325
# At random state  2 testing accuracy is :  0.14361110780240227
#
#
# At random state  3 traning accuracy is :  0.9601755396569429
# At random state  3 testing accuracy is :  0.5873110924043234
#
#
# At random state  4 traning accuracy is :  0.948037274737643
# At random state  4 testing accuracy is :  0.8402135389418618
#
#
# At random state  5 traning accuracy is :  0.9567484096745109
# At random state  5 testing accuracy is :  0.4929666147517384
#
#
# At random state  6 traning accuracy is :  0.950490693866655
# At random state  6 testing accuracy is :  0.7597514339615508
#
#
# At random state  7 traning accuracy is :  0.9294170260650507
# At random state  7 testing accuracy is :  0.7703829071733721
#
#
# At random state  8 traning accuracy is :  0.9577042370655368
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.3,random_state=44)

rd.fit(x_train,y_train)
predrd=rd.predict(x_test)
print(r2_score(y_test,predrd))
mean_squared_error(y_test,predrd)
# Out:
# 0.8907313512077528
# 12.068115211054852

# %% [markdown]
# Support Vector Regression

# %%
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.3,random_state=i)
    sv.fit(x_train,y_train)
    predtr=sv.predict(x_train)
    predte=sv.predict(x_test)
    print("At random state ",i,"traning accuracy is : ",r2_score(y_train,predtr))
    print("At random state ",i,"testing accuracy is : ",r2_score(y_test,predte))
    print('\n')
# Out:
# At random state  1 traning accuracy is :  0.16129649995594442
# At random state  1 testing accuracy is :  0.10983015886543834
#
#
# At random state  2 traning accuracy is :  0.24728996007845339
# At random state  2 testing accuracy is :  -2.0467098430257566
#
#
# At random state  3 traning accuracy is :  0.23127384822723085
# At random state  3 testing accuracy is :  0.0788395928394191
#
#
# At random state  4 traning accuracy is :  0.1908967004703661
# At random state  4 testing accuracy is :  -0.013465019504901976
#
#
# At random state  5 traning accuracy is :  0.2075932391996782
# At random state  5 testing accuracy is :  0.1120648102616465
#
#
# At random state  6 traning accuracy is :  0.2269856657670999
# At random state  6 testing accuracy is :  0.0775675229939854
#
#
# At random state  7 traning accuracy is :  0.18232921848465655
# At random state  7 testing accuracy is :  0.1356115039311061
#
#
# At random state  8 traning accuracy is :  0.23529441297226772
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.3,random_state=54)

sv.fit(x_train,y_train)
predsv=sv.predict(x_test)
print(r2_score(y_test,predsv))
mean_squared_error(y_test,predsv)
# Out:
# 0.14843400203875845
# 33.13748179720781

# %% [markdown]
# Decision Tree Regressor

# %%
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.3,random_state=i)
    dt.fit(x_train,y_train)
    predtr=dt.predict(x_train)
    predte=dt.predict(x_test)
    print("At random state ",i,"traning accuracy is : ",r2_score(y_train,predtr))
    print("At random state ",i,"testing accuracy is : ",r2_score(y_test,predte))
    print('\n')
# Out:
# At random state  1 traning accuracy is :  1.0
# At random state  1 testing accuracy is :  0.5607321131447587
#
#
# At random state  2 traning accuracy is :  1.0
# At random state  2 testing accuracy is :  -1.6466165413533833
#
#
# At random state  3 traning accuracy is :  1.0
# At random state  3 testing accuracy is :  0.5483050847457628
#
#
# At random state  4 traning accuracy is :  1.0
# At random state  4 testing accuracy is :  0.3366730716442493
#
#
# At random state  5 traning accuracy is :  1.0
# At random state  5 testing accuracy is :  -0.5986394557823129
#
#
# At random state  6 traning accuracy is :  1.0
# At random state  6 testing accuracy is :  0.6620171673819741
#
#
# At random state  7 traning accuracy is :  1.0
# At random state  7 testing accuracy is :  -0.38065843621399176
#
#
# At random state  8 traning accuracy is :  1.0
# At random state  8 testing accuracy is :  0.042305703946234785
#
#
# At random state  9 traning accuracy is :  1.0
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.3,random_state=23)

dt.fit(x_train,y_train)
preddt=dt.predict(x_test)
print(r2_score(y_test,preddt))
mean_squared_error(y_test,preddt)
# Out:
# 0.8174397931145951
# 27.88888888888889

# %% [markdown]
# Randon Forest Regressor

# %%
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.3,random_state=i)
    rf.fit(x_train,y_train)
    predtr=rf.predict(x_train)
    predte=rf.predict(x_test)
    print("At random state ",i,"traning accuracy is : ",r2_score(y_train,predtr))
    print("At random state ",i,"testing accuracy is : ",r2_score(y_test,predte))
    print('\n')
# Out:
# At random state  1 traning accuracy is :  0.9177574365643765
# At random state  1 testing accuracy is :  0.7376543261231281
#
#
# At random state  2 traning accuracy is :  0.915902707799287
# At random state  2 testing accuracy is :  -0.3586924812030068
#
#
# At random state  3 traning accuracy is :  0.897958896582042
# At random state  3 testing accuracy is :  0.6202750847457628
#
#
# At random state  4 traning accuracy is :  0.8916142567425814
# At random state  4 testing accuracy is :  0.6991867965962119
#
#
# At random state  5 traning accuracy is :  0.9226734803880919
# At random state  5 testing accuracy is :  0.6810693877551017
#
#
# At random state  6 traning accuracy is :  0.9289607887751232
# At random state  6 testing accuracy is :  0.720081459227468
#
#
# At random state  7 traning accuracy is :  0.937290090537021
# At random state  7 testing accuracy is :  0.45884372427983555
#
#
# At random state  8 traning accuracy is :  0.9328098556927615
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(X_scale,Y,test_size=0.3,random_state=33)

rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(r2_score(y_test,predrf))
mean_squared_error(y_test,predrf)
# Out:
# 0.795327368117058
# 26.24863333333336

# %% [markdown]
# Cross Validation

# %%
from sklearn.model_selection import cross_val_score
#linear
score=cross_val_score(lr,X_scale,Y,cv=5)

print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.38568012 -1.20958303  0.58302396  0.5978706   0.66163185]
# 0.20372470067132803
# 0.7126632304904944

# %%
#Lasso
score=cross_val_score(ls,X_scale,Y,cv=5)

print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.7339085  -1.03951024  0.76233047  0.77700579  0.88437312]
# 0.4236215293647544
# 0.733338773476991

# %%
#Ridge
score=cross_val_score(rd,X_scale,Y,cv=5)

print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.44924736 -1.38522279  0.64064919  0.87041738  0.84162237]
# 0.28334270420538815
# 0.8480136750995537

# %%
#SVR
score=cross_val_score(sv,X_scale,Y,cv=5)

print(score)
print(score.mean())
print(score.std())
# Out:
# [-0.09187329 -1.16944919 -0.01977943 -0.46118472  0.16792819]
# -0.3148716893991814
# 0.4736272084107536

# %%
#Decision tree
score=cross_val_score(dt,X_scale,Y,cv=5)

print(score)
print(score.mean())
print(score.std())
# Out:
# [ -1.475      -11.93421053  -0.06817231   0.50983607  -0.32370283]
# -2.658249920754103
# 4.682710891796555

# %%
#Random Forest
score=cross_val_score(rf,X_scale,Y,cv=5)

print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.08262386 -4.4211      0.41385462  0.38659557  0.81384139]
# -0.5448369099172856
# 1.9520135868752924

# %% [markdown]
# Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
#Linear

grid_para={'normalize':[True,False],'fit_intercept':[True,False],'copy_X':[True,False],'positive':[True,False],'n_jobs':range(1,50,2)}
grid_search=GridSearchCV(estimator=lr,param_grid=grid_para,cv=5)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'n_jobs': range(1, 50, 2), 'normalize': [True, False],
#                          'positive': [True, False]})

# %%
best_para=grid_search.best_params_
print(best_para)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': True, 'positive': True}

# %%
lr=LinearRegression(copy_X=True,fit_intercept=True,n_jobs=1,normalize=True,positive=True)
lr.fit(x_train,y_train)
Predlr=lr.predict(x_test)
print(r2_score(y_test,Predlr))
# Out:
# 0.8198405905482328

# %%
#Lasso
grid_para={'normalize':(True,False),'alpha':[0.001,0.01,0.1,1,10,100,1000],'selection':['cyclic','random'],'positive':(True,False),'max_iter':[1000,2000,3000,4000,5000]}
grid_search=GridSearchCV(estimator=ls,param_grid=grid_para,cv=5)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                          'max_iter': [1000, 2000, 3000, 4000, 5000],
#                          'normalize': (True, False), 'positive': (True, False),
#                          'selection': ['cyclic', 'random']})

# %%
best_para=grid_search.best_params_
print(best_para)
# Out:
# {'alpha': 0.1, 'max_iter': 1000, 'normalize': False, 'positive': False, 'selection': 'random'}

# %%
ls=Lasso(alpha=0.1,max_iter=1000,normalize=False,positive=False,selection='random')
ls.fit(x_train,y_train)
Predls=ls.predict(x_test)
print(r2_score(y_test,Predls))
# Out:
# 0.8315378463840726

# %%
sns.scatterplot(x=y_test,y=Predls,color='r')
plt.plot(y_test,y_test)

# %%
#Ridge
grid_para={'alpha':[1,10,100,1000],'solver':['auto','svd','cholesky','lsqr','saga','sag','lbfgs'],'max_iter':[1000,2000,3000,4000,5000],'copy_X':(True,False),'tol':[0.1,1,1.5,2,2.8,3.5,4]}
grid_search=GridSearchCV(estimator=rd,param_grid=grid_para,cv=5)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1, 10, 100, 1000], 'copy_X': (True, False),
#                          'max_iter': [1000, 2000, 3000, 4000, 5000],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'saga',
#                                     'sag', 'lbfgs'],
#                          'tol': [0.1, 1, 1.5, 2, 2.8, 3.5, 4]})

# %%
best_para=grid_search.best_params_
print(best_para)
# Out:
# {'alpha': 10, 'copy_X': False, 'max_iter': 1000, 'solver': 'sag', 'tol': 0.1}

# %%
rd=Ridge(alpha=10,copy_X=False,max_iter=1000,solver='sag',tol=0.1)
rd.fit(x_train,y_train)
Predrd=rd.predict(x_test)
print(r2_score(y_test,Predrd))
# Out:
# 0.7267818282412815

# %%
sns.scatterplot(x=y_test,y=Predrd,color='r')
plt.plot(y_test,y_test)

# %%
#SVR
grid_para={'degree':range(1,10,1),'gamma':['scale','auto'],'cache_size':range(50,500,20),'kernel':['linear','poly','rbf'],'max_iter':[1000,2000,3000,4000,5000],'tol':[0.1,1,1.5,2,2.8,3.5,4]}
grid_search=GridSearchCV(estimator=sv,param_grid=grid_para,cv=5)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'cache_size': range(50, 500, 20),
#                          'degree': range(1, 10), 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf'],
#                          'max_iter': [1000, 2000, 3000, 4000, 5000],
#                          'tol': [0.1, 1, 1.5, 2, 2.8, 3.5, 4]})

# %%
best_para=grid_search.best_params_
print(best_para)
# Out:
# {'cache_size': 50, 'degree': 1, 'gamma': 'scale', 'kernel': 'linear', 'max_iter': 1000, 'tol': 2.8}

# %%
sv=SVR(cache_size=50,degree=1,gamma='scale',kernel='linear',max_iter=1000,tol=2.8)
sv.fit(x_train,y_train)
Predsv=sv.predict(x_test)
print(r2_score(y_test,Predsv))
# Out:
# 0.8370865435291239

# %%
sns.scatterplot(x=y_test,y=Predsv,color='r')
plt.plot(y_test,y_test)

# %%
#DTR
grid_para={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],'splitter':['best','random'],'max_depth':range(1,20,2),'min_samples_split':range(2,20,1),'max_features':['auto','sqrt','log2']}
grid_search=GridSearchCV(estimator=dt,param_grid=grid_para,cv=5)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': range(1, 20, 2),
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': range(2, 20),
#                          'splitter': ['best', 'random']})

# %%
best_para=grid_search.best_params_
print(best_para)
# Out:
# {'criterion': 'friedman_mse', 'max_depth': 11, 'max_features': 'auto', 'min_samples_split': 16, 'splitter': 'random'}

# %%
dt=DecisionTreeRegressor(criterion='friedman_mse',max_depth=11,max_features='auto',min_samples_split=16,splitter='random')
dt.fit(x_train,y_train)
Preddt=dt.predict(x_test)
print(r2_score(y_test,Preddt))
# Out:
# 0.5310574701578745

# %%
sns.scatterplot(x=y_test,y=Preddt,color='r')
plt.plot(y_test,y_test)

# %%
#Random Forest
grid_para={'n_estimators':[90,100,115,130],'criterion':['squared_error','absolute_error','poisson'],'max_depth':range(2,20,1),'max_features': ['auto','log2','sqrt']}
grid_search=GridSearchCV(estimator=rf,param_grid=grid_para,cv=5)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': range(2, 20),
#                          'max_features': ['auto', 'log2', 'sqrt'],
#                          'n_estimators': [90, 100, 115, 130]})

# %%
best_para=grid_search.best_params_
print(best_para)
# Out:
# {'criterion': 'poisson', 'max_depth': 11, 'max_features': 'sqrt', 'n_estimators': 90}

# %%
rf=RandomForestRegressor(criterion='poisson',max_depth=11,max_features='sqrt',n_estimators=90)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(r2_score(y_test,predrf))
# Out:
# 0.5274577537828546

# %%
sns.scatterplot(x=y_test,y=predrf,color='r')
plt.plot(y_test,y_test)

# %% [markdown]
# The best model is Lasso Regression with r2 score of 83.15%.

# %%
import pickle
filename="Baseball.pkl"
pickle.dump(ls,open(filename, 'wb'))

# %% [markdown]
# Conclusion

# %%
model=pickle.load(open("Baseball.pkl",'rb'))
result=model.score(x_test,y_test)
print(result*100)
# Out:
# 83.15378463840726

# %%
Accuracy=pd.DataFrame([model.predict(x_test),Predls],index=['Predicted','Original'])
Accuracy
# Out:
#                    0          1          2          3          4          5  \
# Predicted  83.173166  90.388137  89.293225  90.032021  68.662314  80.268772
# Original   83.173166  90.388137  89.293225  90.032021  68.662314  80.268772
#
#                   6          7          8
# Predicted  68.52326  86.720236  58.176542
# Original   68.52326  86.720236  58.176542
